# %%
import pandas as pd
import json

# %%
df=pd.read_csv("weather.csv")
print(df)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
df[df['MaxTemp'] <= 15]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 141     13.0     14.8       0.0          8.2       0.0          SE
# 154      7.0     14.3       2.6          9.6       9.7         WNW
# 179      4.3     11.3       7.2          4.4       5.6           W
# 180     -2.1     13.8       0.2          1.8       9.5         NNW
# 181     -1.8     14.8       0.0          1.4       7.0           N
# ..       ...      ...       ...          ...       ...         ...
# 309      5.8     12.4       0.0          1.6       0.0          SE
# 313     -3.7     14.7       0.0          3.4      10.9         SSE
# 320      3.9     13.2       3.4          6.6      11.0         WNW
# 321      0.7     14.1       0.0          5.6       9.0         ENE
# 356      3.4     15.0       0.8          4.8      11.7           S
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 141           30.0        ESE        ESE           9.0  ...           62
# ...

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df[df['Sunshine'] == 8.600000	]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 113     12.7     28.6       6.6          3.2       8.6           W
# 211     -0.1     18.0       0.0          2.0       8.6         NaN
# 271      0.8     12.2       0.0          1.8       8.6         NaN
# 311     -0.9     16.7       0.0          2.8       8.6          NW
# 322      1.1     18.0       0.0          1.6       8.6         NNW
# 352      6.7     24.7       0.0          5.4       8.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 113           50.0        NaN          W           NaN  ...           42
# 211            NaN          N        NNW           2.0  ...           46
# 271            NaN          S          S          19.0  ...           49
# 311           35.0        WNW         NW           7.0  ...           33
# 322           39.0        NNW        NNW           2.0  ...           36
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
df.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
df.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
df.describe().transpose()
# Out:
#                count         mean        std    min       25%      50%  \
# MinTemp        366.0     7.265574   6.025800   -5.3     2.300     7.45
# MaxTemp        366.0    20.550273   6.690516    7.6    15.025    19.65
# Rainfall       366.0     1.428415   4.225800    0.0     0.000     0.00
# Evaporation    366.0     4.521858   2.669383    0.2     2.200     4.20
# Sunshine       363.0     7.909366   3.481517    0.0     5.950     8.60
# WindGustSpeed  364.0    39.840659  13.059807   13.0    31.000    39.00
# WindSpeed9am   359.0     9.651811   7.951929    0.0     6.000     7.00
# WindSpeed3pm   366.0    17.986339   8.856997    0.0    11.000    17.00
# Humidity9am    366.0    72.035519  13.137058   36.0    64.000    72.00
# Humidity3pm    366.0    44.519126  16.850947   13.0    32.250    43.00
# Pressure9am    366.0  1019.709016   6.686212  996.5  1015.350  1020.15
# Pressure3pm    366.0  1016.810383   6.469422  996.8  1012.800  1017.40
# ...

# %%
df.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
df=df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
cols=df.columns.tolist()

# %%
cols
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustDir',
#  'WindGustSpeed',
#  'WindDir9am',
#  'WindDir3pm',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm',
#  'RainToday',
#  'RISK_MM',
#  'RainTomorrow']

# %%
for i, col in enumerate(cols):
    if '(' in col:
        cols[i] = col + ")"
        df.cols= cols
    print(df.columns)
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
# ...

# %%
df.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
df.to_csv('cln_weather_data.csv', encoding='utf-8', index=False)

# %%
df['MaxTemp'].value_counts()
# Out:
# MaxTemp
# 14.8    5
# 20.9    5
# 12.2    5
# 15.5    5
# 11.6    5
#        ..
# 17.1    1
# 30.3    1
# 35.8    1
# 21.2    1
# 30.7    1
# Name: count, Length: 187, dtype: int64

# %%
df[df['Rainfall'] <= 3.6]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 5        6.2     16.9       0.0          5.8       8.2          SE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df.groupby('WindGustDir').get_group('NW')
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 13      12.1     30.9       0.0          6.2      12.4          NW
# 14      10.1     31.2       0.0          8.8      13.1          NW
# ..       ...      ...       ...          ...       ...         ...
# 352      6.7     24.7       0.0          5.4       8.6          NW
# 353      8.3     28.5       0.0          5.8       9.8          NW
# 354     11.3     27.4       0.2          7.6      12.1          NW
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
fig = plt.figure()
#ax = fig.add_axes([0,1,1,1])
plt.bar(df['Cloud3pm'],df['RainTomorrow'],color = ['maroon','red'])
plt.title('Bar Chart')
plt.xlabel("Clouds")
plt.ylabel("RainTommorrow")
plt.show()
# Out:
# <BarContainer object of 366 artists>
# Text(0.5, 1.0, 'Bar Chart')
# Text(0.5, 0, 'Clouds')
# Text(0, 0.5, 'RainTommorrow')

# %%
weather = dict(df['RainTomorrow'].value_counts())
series = pd.Series(weather.values(), index=weather.keys(), name="Weather")
series.plot.pie(figsize=(5, 5))
# Out:
# <Axes: ylabel='Weather'>

# %%
weather = dict(df['RainToday'].value_counts())
series = pd.Series(weather.values(), index=weather.keys(), name="Weather")
series.plot.pie(figsize=(5, 5))
# Out:
# <Axes: ylabel='Weather'>

# %%
df[(df['WindDir9am'] == 'E')& (df['WindDir3pm'] == 'E')]
# Out:
#     MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 25     15.6     26.9       0.0          6.8       8.9           E
# 26     13.3     22.2       0.2          6.6       2.3         ENE
#
#     WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 25           41.0          E          E           6.0  ...           48
# 26           39.0          E          E          20.0  ...           55
#
#     Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 25       1019.7       1016.5         2         4     19.8     25.1         No
# 26       1021.0       1018.6         7         7     16.5     21.2         No
#
#     RISK_MM RainTomorrow
# 25      0.2           No
# 26      0.0           No
#
# [2 rows x 22 columns]

# %%
df[(df['RainToday'] == 'No')& (df['WindDir3pm'] == 'E')]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 7        8.3     17.0       0.0          5.6       4.6           E
# 21      16.4     19.4       0.4          9.2       0.0           E
# 25      15.6     26.9       0.0          6.8       8.9           E
# 26      13.3     22.2       0.2          6.6       2.3         ENE
# 34      14.5     21.8       0.0          8.4       9.8         ENE
# 40      11.8     18.5       0.6          4.8       2.3         ENE
# 41      11.7     21.5       0.0          4.2       7.3         ENE
# 42       9.6     20.3       0.0          5.0       3.6          SE
# 47       7.5     20.9       0.0          6.6       8.7         ENE
# 65      12.1     27.5       0.0          7.4      11.7          NE
# 83       9.9     24.4       0.0          5.8      10.8          NE
# 106     10.8     25.2       0.0          5.6      12.6         ENE
# ...
